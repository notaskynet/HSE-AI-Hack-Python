# %%
from app.models.qwen import Qwen

model = Qwen(system_prompt="Ты - профессиональный программист и ментор.")

# %%
model.ask("Что такое динамическое программирование?")
# Out:
# 'Динамическое программирование (DP) — это методика решения задач, основанный на использовании существующих решений для подобных же или схожих задач в будущем. В отличие от алгоритмов последовательного выполнения шагов, где каждый шаг зависит только от предыдущего, в динамическом программировании текущий шаг также может зависеть от следующих.\n\nОсновные принципы динамического программирования:\n\n1. Разбиение задачи на части: Прежде всего, задача разбивается на более простые подзадачи.\n\n2. Решение подзадач: Подзадачи решаются по-разному, но результат их решения может быть воспользован в дальнейшем при решении других задач.\n\n3. Сохранение результата: Результат решения каждой подзадачи сохраняется, чтобы использовать его при решении других подзадач.\n\n4. Использование рекурсии: Если есть возможность, можно использовать рекурсию для обхода всех возможных вариантов решения задачи.\n\n5. Сокращение пересчета: Правильное использование хранения результата позволяет избежать повторного 
# ...
